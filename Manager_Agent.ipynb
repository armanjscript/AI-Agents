# %%
# !pip install -q crewai crewai['tools'] langchain langchain-groq
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.5/42.5 kB 1.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 3.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.0/235.0 kB 8.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 40.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.0/134.0 kB 9.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 50.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.9/542.9 kB 29.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.9/121.9 kB 8.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.4/71.4 kB 5.5 MB/s eta 0:00:00
# ...

# %%
from crewai import Agent, Task, Crew, Process
from langchain_groq import ChatGroq
import os
import time

# Set your API keys
os.environ["GROQ_API_KEY"] = "YOUR_GROQ_API_KEY"
os.environ["OPENAI_API_KEY"] = "YOUR_OPENAI_API_KEY"  # Add your OpenAI API key here
os.environ["GEMINI_API_KEY"] = "YOUR_GOOGLE_API_KEY"

# Initialize the Google Gemini model
llm = ChatGroq(temperature=0.5, groq_api_key=os.getenv("GROQ_API_KEY"), model_name="groq/deepseek-r1-distill-llama-70b")


def manager_agent():

  researcher = Agent(
        role="Researcher",
        goal="Conduct through research and analysis on AI and AI Agents",
        backstory="You are an expert researcher, specialized in technology, software engineering, AI and startups.",
        allow_delegation=False,
        llm=llm,
    )

  writer = Agent(
        role="Senior Writer",
        goal="Create compelling content about AI and AI Agents",
        backstory="You are a senior writer, specialized in technology, software engineering, AI and startups. You work as a freelancer and are currently writing content for a new client.",
        allow_delegation=False,
        llm=llm,
    )

  task = Task(
      description="Generate a list of 5 interesting ideas for an article, the write one captivating paragraph for each idea that showcases the potential of a full article on this topic. Return the list of ideas with their paragraphs and your notes.",
      expected_output="5 bullet points, each with a paragraph and accompanying notes."
  )

  manager = Agent(
      role="Project Manager",
      goal="Efficiently manage the crew and ensure high-quality task completion",
      backstory="You are an experienced project manager, skilled in overseeing complex projects and guiding teams to success. Your role is to coordinate the efforts of the crew members, ensuring that each task is completed on time and to the highest standard.",
      allow_delegation=True,
      llm=llm,
  )

  crew = Crew(
      agents=[researcher, writer],
      tasks=[task],
      manager_agent=manager,
      process=Process.hierarchical,
  )

  result=crew.kickoff()
  print(result)



# Run the hierarchical_agent function
if __name__ == "__main__":
    manager_agent()
# Out:
# WARNING:opentelemetry.trace:Overriding of current TracerProvider is not allowed
# **1. "Revolutionizing Customer Service: The Rise of AI Agents"**
#
# AI agents are transforming the customer service landscape, offering 24/7 support and personalized experiences. These agents can handle multiple inquiries simultaneously, reducing wait times and improving satisfaction. However, as they become more prevalent, businesses must address challenges like handling complex emotional situations and maintaining a human touch. This article will explore the benefits and hurdles of integrating AI in customer service, featuring case studies from leading companies.
#
# **Notes:**
# - Highlight companies successfully using AI agents.
# - Discuss potential job displacement and the need for human oversight.
#
# **2. "AI in Healthcare: Transforming Diagnosis and Treatment"**
#
# ...
